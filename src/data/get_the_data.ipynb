# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="96ngbZe4GYh75xyBeOXj")
project = rf.workspace("hack-ssxf3").project("car-accident-detection-ctumy")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to car-accident-detection-1 in yolov8:: 100%|██████| 1252/1252 [00:01<00:00, 647.39it/s]
